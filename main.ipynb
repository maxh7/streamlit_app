# %% [markdown]
# Analyse Beispieldaten:

# %%
import pandas as pd
import numpy as np

# %%
df_example = pd.read_json("example.json")

# %% [markdown]
# Show Some Data

# %%
df_example.head()
# Out:
#                       sensor          time  seconds_elapsed         z
# 0              Accelerometer  1.679931e+18    -2.408603e+06  0.000000  \
# 1  AccelerometerUncalibrated  1.682339e+18     1.199097e-02 -0.871216
# 2  AccelerometerUncalibrated  1.682339e+18     2.205371e-02 -0.800888
# 3  AccelerometerUncalibrated  1.682339e+18     3.211694e-02 -0.763306
# 4  AccelerometerUncalibrated  1.682339e+18     4.217896e-02 -0.783676
#
#           y         x  relativeAltitude  pressure  version device name
# 0  0.000000  0.000000               NaN       NaN      NaN         NaN  \
# 1 -0.588531  0.164291               NaN       NaN      NaN         NaN
# 2 -0.589920  0.162689               NaN       NaN      NaN         NaN
# 3 -0.584030  0.162445               NaN       NaN      NaN         NaN
# 4 -0.564880  0.167526               NaN       NaN      NaN         NaN
#
#   recording time platform  appVersion device id sensors sampleRateMs
# 0            NaN      NaN         NaN       NaN     NaN          NaN
# 1            NaN      NaN         NaN       NaN     NaN          NaN
# 2            NaN      NaN         NaN       NaN     NaN          NaN
# 3            NaN      NaN         NaN       NaN     NaN          NaN
# 4            NaN      NaN         NaN       NaN     NaN          NaN

# %% [markdown]
# Data structure and types:

# %%
df_example.columns
# Out:
# Index(['sensor', 'time', 'seconds_elapsed', 'z', 'y', 'x', 'relativeAltitude',
#        'pressure', 'version', 'device name', 'recording time', 'platform',
#        'appVersion', 'device id', 'sensors', 'sampleRateMs'],
#       dtype='object')

# %%
#preprocessing data
df_example['time'] = pd.to_datetime(df_example['time'])

display(df_example.head(5))
# Out:
#                       sensor                          time  seconds_elapsed
# 0              Accelerometer 2023-03-27 15:28:11.764102144    -2.408603e+06  \
# 1  AccelerometerUncalibrated 2023-04-24 12:31:34.532990976     1.199097e-02
# 2  AccelerometerUncalibrated 2023-04-24 12:31:34.543053824     2.205371e-02
# 3  AccelerometerUncalibrated 2023-04-24 12:31:34.553116928     3.211694e-02
# 4  AccelerometerUncalibrated 2023-04-24 12:31:34.563179008     4.217896e-02
#
#           z         y         x  relativeAltitude  pressure  version
# 0  0.000000  0.000000  0.000000               NaN       NaN      NaN  \
# 1 -0.871216 -0.588531  0.164291               NaN       NaN      NaN
# 2 -0.800888 -0.589920  0.162689               NaN       NaN      NaN
# 3 -0.763306 -0.584030  0.162445               NaN       NaN      NaN
# 4 -0.783676 -0.564880  0.167526               NaN       NaN      NaN
#
#   device name recording time platform  appVersion device id sensors
# 0         NaN            NaN      NaN         NaN       NaN     NaN  \
# 1         NaN            NaN      NaN         NaN       NaN     NaN
# 2         NaN            NaN      NaN         NaN       NaN     NaN
# 3         NaN            NaN      NaN         NaN       NaN     NaN
# 4         NaN            NaN      NaN         NaN       NaN     NaN
#
#   sampleRateMs
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df_example = df_example.set_index('time')

# %%
df_example['sensor'].unique()
# Out:
# array(['Accelerometer', 'AccelerometerUncalibrated', 'Barometer',
#        'Metadata'], dtype=object)

# %%
df_example_acc = df_example[df_example['sensor'] == 'AccelerometerUncalibrated']
display(df_example_acc.head(2))
# Out:
#                                                   sensor  seconds_elapsed
# time
# 2023-04-24 12:31:34.532990976  AccelerometerUncalibrated         0.011991  \
# 2023-04-24 12:31:34.543053824  AccelerometerUncalibrated         0.022054
#
#                                       z         y         x  relativeAltitude
# time
# 2023-04-24 12:31:34.532990976 -0.871216 -0.588531  0.164291               NaN  \
# 2023-04-24 12:31:34.543053824 -0.800888 -0.589920  0.162689               NaN
#
#                                pressure  version device name recording time
# time
# 2023-04-24 12:31:34.532990976       NaN      NaN         NaN            NaN  \
# 2023-04-24 12:31:34.543053824       NaN      NaN         NaN            NaN
#
#                               platform  appVersion device id sensors
# time
# 2023-04-24 12:31:34.532990976      NaN         NaN       NaN     NaN  \
# 2023-04-24 12:31:34.543053824      NaN         NaN       NaN     NaN
#
#                               sampleRateMs
# time
# 2023-04-24 12:31:34.532990976          NaN
# 2023-04-24 12:31:34.543053824          NaN

# %%
df_example_acc = df_example_acc[['z', 'y', 'x']]
display(df_example_acc.head(3))
# Out:
#                                       z         y         x
# time
# 2023-04-24 12:31:34.532990976 -0.871216 -0.588531  0.164291
# 2023-04-24 12:31:34.543053824 -0.800888 -0.589920  0.162689
# 2023-04-24 12:31:34.553116928 -0.763306 -0.584030  0.162445

# %%
df_example_acc.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='time'>
